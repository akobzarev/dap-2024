# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": [],
      "toc_visible": true
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {
        "id": "HFpGRM5ag5VU"
      },
      "outputs": [],
      "source": []
    },
    {
      "cell_type": "markdown",
      "source": [
        "# **Отчёт о 1 лабораторной работе.**\n",
        "1.   Была создана учетная запись на GitHub и Google Colab\n",
        "2.   Проведена настройка интеграции Google Colab и GitHub\n",
        "3.   Содан форк репозитория:https://github.com/chebotarevsa/dap-2024\n",
        "4.   Сохранен отчет.\n",
        "5.   Проведен пул реквест:https://github.com/chebotarevsa/dap-2024.\n",
        "\n",
        "\n",
        "\n",
        "\n",
        "\n",
        "\n",
        "\n"
      ],
      "metadata": {
        "id": "vbZd8b9PKRaC"
      }
    }
  ]
}
