# %% [markdown]
# # **Отчёт по лабораторной работе 1**

# %% [markdown]
# 1.   Была создана учетная запись на GitHub и Google Cola.
# 2.   Проведена настройка интеграции Google Cola и GitHub.
# 3.   Содан форк репозитория:https://github.com/chebotarevsa/dap-2024
# 4.   Сохранен отчет.
# 5.   Проведен пул реквест:https://github.com/chebotarevsa/dap-2024
